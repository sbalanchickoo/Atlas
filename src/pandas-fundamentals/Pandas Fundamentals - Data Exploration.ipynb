# %%
import pandas as pd
import numpy as np
import requests
import json

cols = ['ATCOCode', 'CommonName',
       'CommonNameLang', 'ShortCommonName', 'ShortCommonNameLang', 'Landmark',
       'LandmarkLang', 'Street', 'StreetLang', 'Crossing', 'CrossingLang',
       'Indicator', 'IndicatorLang', 'Bearing', 'NptgLocalityCode',
       'LocalityName', 'ParentLocalityName', 'GrandParentLocalityName', 'Town',
       'TownLang', 'Suburb', 'SuburbLang', 'LocalityCentre', 'GridType',
       'Easting', 'Northing', 'Longitude', 'Latitude', 'StopType',
       'BusStopType', 'TimingStatus', 'DefaultWaitTime',
       'CreationDateTime',
       'RevisionNumber', 'Modification', 'Status']

df = pd.read_csv("Data/govuk/Stops1.csv", low_memory=False, index_col='ATCOCode', usecols=cols)
df.head()
# Out:
#                   CommonName CommonNameLang ShortCommonName  \
# ATCOCode
# 0100053316  Broad Walk Shops             en             NaN
# 0100053264     Alberton Road             en             NaN
# 0100053308       Counterslip             en             NaN
# 0100053306      Risdale Road             en             NaN
# 010000015    Kings Head Lane             en             NaN
#
#            ShortCommonNameLang Landmark LandmarkLang           Street  \
# ATCOCode
# 0100053316                 NaN      NaN          NaN              NaN
# 0100053264                 NaN      NaN          NaN    Alberton Road
# 0100053308                 NaN      NaN          NaN      Counterslip
# 0100053306                 NaN      NaN          NaN     Risdale Road
# 010000015                  NaN      NaN          NaN  Kings Head Lane
#
#            StreetLang Crossing CrossingLang  ... Longitude   Latitude  \
# ATCOCode                                     ...
# ...

# %%
df[df['CommonName'].notnull()].head()
# Out:
#            NaptanCode PlateCode  CleardownCode        CommonName  \
# ATCOCode
# 0100053316    bstjpdm       NaN            NaN  Broad Walk Shops
# 0100053264    bstmjdp       NaN            NaN     Alberton Road
# 0100053308    bstgtgj       NaN            NaN       Counterslip
# 0100053306    bstapjm       NaN            NaN      Risdale Road
# 010000015     bstpgpa       NaN            NaN   Kings Head Lane
#
#            CommonNameLang ShortCommonName ShortCommonNameLang Landmark  \
# ATCOCode
# 0100053316             en             NaN                 NaN      NaN
# 0100053264             en             NaN                 NaN      NaN
# 0100053308             en             NaN                 NaN      NaN
# 0100053306             en             NaN                 NaN      NaN
# 010000015              en             NaN                 NaN      NaN
#
#            LandmarkLang           Street  ... TimingStatus DefaultWaitTime  \
# ATCOCode                                  ...
# ...

# %%
df.columns
# Out:
# Index(['NaptanCode', 'PlateCode', 'CleardownCode', 'CommonName',
#        'CommonNameLang', 'ShortCommonName', 'ShortCommonNameLang', 'Landmark',
#        'LandmarkLang', 'Street', 'StreetLang', 'Crossing', 'CrossingLang',
#        'Indicator', 'IndicatorLang', 'Bearing', 'NptgLocalityCode',
#        'LocalityName', 'ParentLocalityName', 'GrandParentLocalityName', 'Town',
#        'TownLang', 'Suburb', 'SuburbLang', 'LocalityCentre', 'GridType',
#        'Easting', 'Northing', 'Longitude', 'Latitude', 'StopType',
#        'BusStopType', 'TimingStatus', 'DefaultWaitTime', 'Notes', 'NotesLang',
#        'AdministrativeAreaCode', 'CreationDateTime', 'ModificationDateTime',
#        'RevisionNumber', 'Modification', 'Status'],
#       dtype='object')

# %%
df[(df['CommonNameLang'] !='en') & (df['CommonNameLang'].notnull())].head()
# Out:
# Empty DataFrame
# Columns: [CommonName, CommonNameLang, ShortCommonName, ShortCommonNameLang, Landmark, LandmarkLang, Street, StreetLang, Crossing, CrossingLang, Indicator, IndicatorLang, Bearing, NptgLocalityCode, LocalityName, ParentLocalityName, GrandParentLocalityName, Town, TownLang, Suburb, SuburbLang, LocalityCentre, GridType, Easting, Northing, Longitude, Latitude, StopType, BusStopType, TimingStatus, DefaultWaitTime, CreationDateTime, RevisionNumber, Modification, Status]
# Index: []
#
# [0 rows x 35 columns]

# %%
cols = ['ATCOCode', 'ShortCommonName', 'ShortCommonNameLang', 'Landmark',
       'LandmarkLang', 'Street', 'Crossing', 'Indicator', 'IndicatorLang', 
        'Bearing', 'NptgLocalityCode',
       'LocalityName', 'ParentLocalityName', 'GrandParentLocalityName', 'Town',
       'TownLang', 'Suburb', 'LocalityCentre', 'GridType',
       'Easting', 'Northing', 'Longitude', 'Latitude', 'StopType',
       'BusStopType', 'TimingStatus', 'DefaultWaitTime',
       'CreationDateTime',
       'RevisionNumber', 'Modification', 'Status']

df2 = pd.read_csv('Stops1.csv', low_memory=False, index_col='ATCOCode', usecols=cols)
df2.head()
# Out:
#            ShortCommonName ShortCommonNameLang Landmark LandmarkLang  \
# ATCOCode
# 0100053316             NaN                 NaN      NaN          NaN
# 0100053264             NaN                 NaN      NaN          NaN
# 0100053308             NaN                 NaN      NaN          NaN
# 0100053306             NaN                 NaN      NaN          NaN
# 010000015              NaN                 NaN      NaN          NaN
#
#                      Street Crossing Indicator IndicatorLang Bearing  \
# ATCOCode
# 0100053316              NaN      NaN    Stop B            en      SW
# 0100053264    Alberton Road      NaN  NE-bound            en      NE
# 0100053308      Counterslip      NaN  SW-bound            en      SW
# 0100053306     Risdale Road      NaN  SW-bound            en      SW
# 010000015   Kings Head Lane      NaN    Stop D            en      SE
#
#            NptgLocalityCode  ... Longitude   Latitude StopType BusStopType  \
# ATCOCode                     ...
# ...

# %%
df2.drop(df2[df2['Status'] == 'del'].index, inplace=True)

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 265403 entries, 0100BRP90168 to 4400MO0685
# Data columns (total 30 columns):
# ShortCommonName            53223 non-null object
# ShortCommonNameLang        21689 non-null object
# Landmark                   164325 non-null object
# LandmarkLang               32913 non-null object
# Street                     255351 non-null object
# Crossing                   39218 non-null object
# Indicator                  260511 non-null object
# IndicatorLang              95999 non-null object
# Bearing                    256044 non-null object
# NptgLocalityCode           265403 non-null object
# LocalityName               265403 non-null object
# ParentLocalityName         109606 non-null object
# GrandParentLocalityName    5431 non-null object
# Town                       102668 non-null object
# TownLang                   8028 non-null object
# Suburb                     58466 non-null object
# ...

# %%
df2['DefaultWaitTime'].count()
# Out:
# 0

# %%
del df2['DefaultWaitTime']
